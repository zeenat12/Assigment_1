# %% [markdown]
# ## Q1. What is multiprocessing in python? Why is it useful?

# %% [markdown]
# multiprocessing refers to the ability of a system to support more than one processor at the same time.
# Application in a multiprocessing system are broken to smaller routines that run independently.
# the operating system allocates there threads to the processor improving performance of the system.

# %% [markdown]
# **why is it used
# Suppose there are different employees, each to perform a specific task. It becomes simpler, right? That’s why multiprocessing in Python becomes essential. The smaller task threads act like different employees, making it easier to handle and manage various processes.

# %% [markdown]
# ## Q.2 What are the differences between multiprocessing and multithreading?

# %% [markdown]
# Multiprocessing: i) It is technique where multiple process run across multiple cores at the same time.
#                  ii) Each program has its own interpreter that execute different processes at the same time.
#                  iii) Multiple processes actually run parallely as the multiprocessing madule streamline the independent
#                       processe by using sub-processing
#
# Multithreading : i) It is a technique where multiple thread are generated by a single process at the same time.
#                  ii) the GIL does not allow the threads to run simualtenously.
#                  iii) It gives a feeling that threads are running simualtenously but they work concurrently.

# %% [markdown]
# ## Q3. Write a python code to create a process using the multiprocessing module.

# %%
import multiprocessing
def test():
    print('This is my function')
    
if __name__ == '__main__':
    m = multiprocessing.Process(target = test)
    print('This is my process module')
    m.start()
    m.join()
# Out:
# This is my process module
# This is my function

# %% [markdown]
# ## Q4. What is a multiprocessing pool in python? Why is it used?

# %% [markdown]
# A multiprocessing pool in Python is a high-level abstraction provided by the multiprocessing module that allows you to easily manage and distribute the execution of tasks across multiple processes. A pool maintains a group of worker processes that can be used to execute tasks in parallel. It abstracts away much of the complexity involved in creating and managing individual processes, making it simpler to achieve parallelism in your code.
#
# The main purpose of using a multiprocessing pool is to efficiently parallelize the execution of a function across a set of input values. Here's how it works:
#
# Creating a Pool: You create a pool of worker processes using the Pool class from the multiprocessing module. You specify the number of worker processes you want in the pool. Each worker process is a separate process that can execute tasks concurrently.
#
# Mapping Tasks: Once the pool is created, you can use its map() or imap() method to apply a given function to a collection of input values. The pool automatically distributes the tasks across the worker processes, ensuring that the tasks are executed in parallel.
#
# Results: The map() method returns a list of results, where each result corresponds to the output of applying the function to each input value. If you use imap(), you get an iterator over the results, which can be useful for processing large amounts of data without loading all the results into memory at once.

# %% [markdown]
# ## Q5. How can we create a pool of worker processes in python using the multiprocessing module?

# %%
import multiprocessing
def square(n):
    return n**2
if __name__ == '__main__':
    with multiprocessing.Pool(processes=5) as pool :
        out =pool.map(square , [3,4,5,6,6,7,87,8,8])
        print(out)
# Out:
# [9, 16, 25, 36, 36, 49, 7569, 64, 64]

# %% [markdown]
# ## Q6. Write a python program to create 4 processes, each process should print a different number using the multiprocessing module in python.

# %%
import multiprocessing

def print_number(number):
    print(f"Process {number}: {number}")

if __name__ == "__main__":
    processes = []
    
    for i in range(1, 5):
        process = multiprocessing.Process(target=print_number, args=(i,))
        processes.append(process)
        process.start()
    
    for process in processes:
        process.join()
# Out:
# Process 1: 1
# Process 2: 2
# Process 3: 3
# Process 4: 4
