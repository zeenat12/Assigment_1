# %% [markdown]
# # Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a web framework that allows developers to build lightweight web applications quickly and easily with Flask Libraries. It was developed by Armin Ronacher, leader of the International Group of Python Enthusiasts(POCCO). It is basically based on the WSGI toolkit and Jinja2 templating engine.

# %% [markdown]
# **Advantages of Flask:**
# 1) Flask is a lightweight backend framework with minimal dependencies.
# 2) Flask is easy to learn because its simple and intuitive API makes it easy to learn and use for beginners.
# 3) Flask is a flexible Framework because it allows you to customize and extend the framework to suit your needs easily.
# 4) Flask can be used with any database like:- SQL and NoSQL and with any Frontend Technology such as React or Angular.
# 5) Flask is great for small to medium projects that do not require the complexity of a large framework.

# %% [markdown]
# # Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "Hello, World!" 
if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# In Flask, app routing refers to the process of mapping URLs (Uniform Resource Locators) to specific functions or views within your web application. This mapping is done using decorators provided by Flask, specifically the `@app.route()` decorator. These decorators define how different parts of your application respond to various URLs.
#
# When a user visits a specific URL in a Flask application, the associated view function is executed. This view function can generate and return an HTTP response, which typically includes HTML content, JSON data, or other types of data that the user's web browser or client can interpret.
#
# App routes in Flask serve several purposes:
#
# 1. **URL Mapping:** Define how different parts of a web application are accessed through URLs.
#
# 2. **Code Organization:** Separate concerns by assigning specific view functions to handle different routes, improving code structure and maintainability.
#
# 3. **Readability:** Make code more understandable by associating URLs directly with functions that perform corresponding actions.
#
# 4. **Modularity:** Treat each route as a module, facilitating testing, debugging, and the addition of new features.
#
# 5. **Dynamic URLs:** Handle variable parts in URLs, like IDs or usernames, for versatile data processing.
#
# 6. **RESTful APIs:** Build RESTful APIs by designating routes for different API endpoints, each serving distinct functions.

# %% [markdown]
# ## Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# ## Company Name: ABC Corporation
# ## Location: India
# ## Contact Detail: 999-999-9999

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# The **url_for() method,** is used to prepare a URL, for a function dynamically, such that, changing URLs, in the application, is avoided. It accepts, the name of the view function, as the first argument, and, any number of keywords, to be sent(to the view function), as the second argument.

# %% [markdown]
# In Flask, the function used for URL building is `url_for()`. This function generates URLs for specified view functions along with any required URL parameters. It abstracts the actual URL paths, making it easier to manage URLs within your application and allowing you to change them without affecting the code that references them.

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route("/")
def home_page():
    return render_template(index.html) 
if __name__=="__main__":
    app.run(debug=True)
